# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Khaleish**
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I have been searching for the next step in my career for sometime now and I believe that this is the field that will not only challenge me but satisfy my need to grow and learn.*

# %% [markdown]
# ### My code should add two binary numbers.

# %%
0+1
# Out:
# 1

# %% [markdown]
# ---
# I am hoping for the following
# 1. Excellent coding skills
# 2. I must finish this course by practicing everyday
# ---
#
# | Monday | Tuesday |
# | --- | --- |
# | yes | no |
